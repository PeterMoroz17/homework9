# %%
# Step 0
import cv2
import dlib
import math
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Step 1
# load an image
img = cv2.imread('C:/photo.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(121), plt.imshow(img)
# Out:
# (<AxesSubplot: >, <matplotlib.image.AxesImage at 0x1eb0afac190>)

# %%
# Step 2
# create a frontal face detector
detector = dlib.get_frontal_face_detector()

# %%
# Step 3
# detect faces in the image
faces = detector(img, 1)

# %%
# Step 4
# draw rectangles around the detected faces
result = np.copy(img)
for face in faces:
    # get the rectangle coordinates, width and height
    x, y, w, h = face.left(), face.top(), face.width(), face.height()
    # to make it more robust to noise, only faces that are big enough will be shown
    if w>=20 and h>=20 :
        cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 3)

# show the image with detected faces
plt.imshow(result)

# %%
# Step 5

# Step 1
# load an image
img = cv2.imread('C:/photo2.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(121), plt.imshow(img)
# Step 2
# create a frontal face detector
detector = dlib.get_frontal_face_detector()
# Step 3
# detect faces in the image
faces = detector(img, 1)
# Step 4
# draw rectangles around the detected faces
result = np.copy(img)
for face in faces:
    # get the rectangle coordinates, width and height
    x, y, w, h = face.left(), face.top(), face.width(), face.height()
    # to make it more robust to noise, only faces that are big enough will be shown
    if w>=20 and h>=20 :
        cv2.rectangle(result, (x, y), (x+w, y+h), (0, 255, 0), 3)

# show the image with detected faces
plt.imshow(result)

# %%
# It works great if face is looking at the camera. However it won't detect if the face isn't fully visible.
